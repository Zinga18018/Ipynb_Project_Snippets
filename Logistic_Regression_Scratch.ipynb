# %% [markdown]
# <a href="https://colab.research.google.com/github/Zinga18018/Ipynb_Project_Snippets/blob/main/Logistic_Regression_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
N = 200
x = torch.randn(N,1)
y = (x > 0).float()

# %%
class Model(nn.Module):
    def __init__(self,hidden=10):
        super().__init__()
        self.linear = nn.Linear(1, 1)
        self.relu = nn.ReLU()
        self .fc1 = nn.Linear(1, hidden)
        self.fc2 = nn.Linear(hidden, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x   # logits

# %%
model = Model(hidden = 10)
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(model.parameters(),lr=0.1)

# %%
for epoch in range(2000):
  logits = model(x)
  loss = loss_fn(logits, y)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if epoch % 100 == 0:
    print(epoch, loss.item())
# Out:
# 0 0.017262887209653854
# 100 0.016606081277132034
# 200 0.016002140939235687
# 300 0.015444495715200901
# 400 0.014927737414836884
# 500 0.014447287656366825
# 600 0.013999254442751408
# 700 0.013580438680946827
# 800 0.013187902048230171
# 900 0.012819050811231136
# 1000 0.01247159019112587
# 1100 0.012143557891249657
# 1200 0.011833315715193748
# 1300 0.011539453640580177
# 1400 0.011260521598160267
# 1500 0.010995444841682911
# 1600 0.010743063874542713
# 1700 0.010502470657229424
# 1800 0.010272732935845852
# 1900 0.010053099133074284

# %%
with torch.no_grad():
  logits = model(x)
  probs = torch.sigmoid(logits)
  preds = (probs > 0.5).float()
  acc = (preds == y).float().mean()
  print(acc)
# Out:
# tensor(1.)
